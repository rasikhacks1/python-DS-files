# %%
import os
import warnings
warnings.simplefilter('ignore')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pip install scikit-image
# Out:
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.8 MB 16.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.4/12.8 MB 15.1 MB/s eta 0:00:01
#    ------- -------------------------------- 2.3/12.8 MB 18.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.2/12.8 MB 18.8 MB/s eta 0:00:01
#    ------------ --------------------------- 4.0/12.8 MB 18.0 MB/s eta 0:00:01
#    -------------- ------------------------- 4.6/12.8 MB 18.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.4/12.8 MB 18.3 MB/s eta 0:00:01
#    ------------------- -------------------- 6.3/12.8 MB 18.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.2/12.8 MB 18.4 MB/s eta 0:00:01
#    ------------------------- -------------- 8.1/12.8 MB 18.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.0/12.8 MB 18.6 MB/s eta 0:00:01
# ...

# %%
import numpy as np
import pandas as pd

# %%
from skimage.io import imread,imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
josephine=os.listdir('C:/Users/aedpu/OneDrive/Desktop/Actreess/Josephine Langford')

# %%
samantha=os.listdir('C:/Users/aedpu/OneDrive/Desktop/Actreess/Samantha')

# %%
tanya=os.listdir('C:/Users/aedpu/OneDrive/Desktop/Actreess/Tanya Ravichandran')

# %%
josephine
# Out:
# ['1.jpg',
#  '10.jpg',
#  '11.jpg',
#  '12.jpg',
#  '13.jpg',
#  '14.jpg',
#  '15.jpg',
#  '16.jpg',
#  '17.jpg',
#  '18.jpg',
#  '19.jpg',
#  '2.jpg',
#  '20.jpg',
#  '21.jpg',
#  '22.jpg',
#  '23.jpg',
#  '24.jpg',
#  '25.jpg',
#  '26.jpg',
#  '27.jpg',
#  '28.jpg',
#  '29.jpg',
#  '3.jpg',
#  '30.jpg',
#  '4.jpg',
#  '5.jpg',
#  '6.jpg',
#  '7.jpg',
#  '8.jpg',
#  '9.jpg']

# %%
samantha
# Out:
# ['1.jpg',
#  '10.jpg',
#  '11.jpg',
#  '12.jpg',
#  '13.jpg',
#  '14.jpg',
#  '15.jpg',
#  '16.jpg',
#  '17.jpg',
#  '18.jpg',
#  '19.jpg',
#  '2.jpg',
#  '20.jpg',
#  '21.jpg',
#  '22.jpg',
#  '23.jpg',
#  '24.jpg',
#  '25.jpg',
#  '26.jpg',
#  '27.jpg',
#  '28.jpg',
#  '29.jpg',
#  '3.jpg',
#  '30.jpg',
#  '4.jpg',
#  '5.jpg',
#  '6.jpg',
#  '7.jpg',
#  '8.jpg',
#  '9.jpg']

# %%
tanya
# Out:
# ['1.jpg',
#  '10.jpg',
#  '11.jpg',
#  '12.jpg',
#  '13.jpg',
#  '14.jpg',
#  '15.jpg',
#  '16.jpg',
#  '17.jpg',
#  '18.jpg',
#  '19.jpg',
#  '2.jpg',
#  '20.jpg',
#  '21.jpg',
#  '22.jpg',
#  '23.jpg',
#  '24.jpg',
#  '25.jpg',
#  '26.jpg',
#  '27.jpg',
#  '28.jpg',
#  '29.jpg',
#  '3.jpg',
#  '30.jpg',
#  '4.jpg',
#  '5.jpg',
#  '6.jpg',
#  '7.jpg',
#  '8.jpg',
#  '9.jpg']

# %%
limit=10
josephine_images=[None]*limit
j=0
for i in josephine:
    if(j<limit):
        josephine_images[j]=imread('C://Users//aedpu//OneDrive//Desktop//Actreess//Josephine Langford//'+i)
        j+=1
    else:
        break

# %%
limit=10
samantha_images=[None]*limit
j=0
for i in samantha:
    if(j<limit):
        samantha_images[j]=imread('C://Users//aedpu//OneDrive//Desktop//Actreess//Samantha//'+i)
        j+=1
    else:
        break

# %%
limit=10
tanya_images=[None]*limit
j=0
for i in tanya:
    if(j<limit):
        tanya_images[j]=imread('C://Users//aedpu//OneDrive//Desktop//Actreess//Tanya Ravichandran//'+i)
        j+=1
    else:
        break

# %%
view = imshow(tanya_images[9])
plt.show()

# %%
view = imshow(samantha_images[8])
plt.show()

# %%
view = imshow(josephine_images[8])
plt.show()

# %%
josephine_gray=[None]*limit
j=0
for i in josephine:
    if(j<limit):
        josephine_gray[j]=rgb2gray(josephine_images[j])
        j+=1
    else:
        break

# %%
view = imshow(josephine_gray[8])
plt.show()

# %%
samantha_gray=[None]*limit
j=0
for i in samantha:
    if(j<limit):
        samantha_gray[j]=rgb2gray(samantha_images[j])
        j+=1
    else:
        break

# %%
view = imshow(samantha_gray[8])
plt.show()

# %%
tanya_gray=[None]*limit
j=0
for i in tanya:
    if(j<limit):
        tanya_gray[j]=rgb2gray(tanya_images[j])
        j+=1
    else:
        break

# %%
view = imshow(tanya_gray[9])
plt.show()

# %%
tanya_images[4].shape
# Out:
# (275, 183, 3)

# %%
for j in range (10):
    ty=tanya_gray[j]
    tanya_gray[j]=resize(ty,(512,512))

# %%
for j in range (10):
    sam=samantha_gray[j]
    samantha_gray[j]=resize(sam,(512,512))

# %%
for j in range (10):
    jp=josephine_gray[j]
    josephine_gray[j]=resize(jp,(512,512))

# %%
view = imshow(tanya_gray[9])
plt.show()

# %%
view = imshow(samantha_gray[1])
plt.show()

# %%
view = imshow(josephine_gray[9])
plt.show()

# %%
len_of_images_josephine=len(josephine_gray)

# %%
len_of_images_josephine
# Out:
# 10

# %%
len_of_images_samantha=len(samantha_gray)

# %%
len_of_images_samantha
# Out:
# 10

# %%
len_of_images_tanya=len(tanya_gray)

# %%
len_of_images_tanya
# Out:
# 10

# %%
image_size_josephine=josephine_gray[1].shape

# %%
image_size_josephine
# Out:
# (512, 512)

# %%
image_size_samantha=samantha_gray[1].shape

# %%
image_size_samantha
# Out:
# (512, 512)

# %%
image_size_tanya=tanya_gray[1].shape

# %%
image_size_tanya
# Out:
# (512, 512)

# %%
512*10
# Out:
# 5120

# %%
flatten_size_josephine=image_size_josephine[0]*image_size_josephine[1]

# %%
flatten_size_josephine
# Out:
# 262144

# %%
flatten_size_samantha=image_size_samantha[0]*image_size_samantha[1]

# %%
flatten_size_samantha
# Out:
# 262144

# %%
flatten_size_tanya=image_size_tanya[0]*image_size_tanya[1]

# %%
flatten_size_tanya
# Out:
# 262144

# %%
for i in range(len_of_images_josephine):
    josephine_gray[i]=np.ndarray.flatten(josephine_gray[i]).reshape(flatten_size_josephine,1)

# %%
for i in range(len_of_images_tanya):
    tanya_gray[i]=np.ndarray.flatten(tanya_gray[i]).reshape(flatten_size_tanya,1)

# %%
for i in range(len_of_images_samantha):
   samantha_gray[i]=np.ndarray.flatten(samantha_gray[i]).reshape(flatten_size_samantha,1)

# %%
josephine_gray=np.dstack(josephine_gray)

# %%
josephine_gray
# Out:
# array([[[0.77217956, 0.9554949 , 0.73917608, ..., 0.69555333,
#          0.09148159, 0.38994457]],
#
#        [[0.78112564, 0.95746585, 0.7333266 , ..., 0.69555333,
#          0.09043993, 0.38217803]],
#
#        [[0.7699124 , 0.96431837, 0.74247821, ..., 0.69555333,
#          0.09187988, 0.38971479]],
#
#        ...,
#
#        [[0.07375922, 0.50127904, 0.22293043, ..., 0.689489  ,
#          0.1483686 , 0.04703808]],
#
#        [[0.07375922, 0.49556035, 0.25153715, ..., 0.68933865,
#          0.14802549, 0.04955033]],
#
#        [[0.07375922, 0.49391551, 0.23325244, ..., 0.68938008,
#          0.1482737 , 0.04696148]]])

# %%
tanya_gray=np.dstack(tanya_gray)

# %%
tanya_gray
# Out:
# array([[[0.36218606, 0.84019121, 0.16323351, ..., 0.15523368,
#          0.60839688, 0.80858687]],
#
#        [[0.36218606, 0.8413066 , 0.16301877, ..., 0.15609152,
#          0.60355648, 0.80383678]],
#
#        [[0.36218606, 0.84024432, 0.16341116, ..., 0.15455966,
#          0.61240121, 0.76946112]],
#
#        ...,
#
#        [[0.07168235, 0.26988454, 0.31191126, ..., 0.93493436,
#          0.43143768, 0.78654392]],
#
#        [[0.07168235, 0.30068934, 0.31133437, ..., 0.9334025 ,
#          0.43347623, 0.78654392]],
#
#        [[0.07168235, 0.2683443 , 0.31165008, ..., 0.93426034,
#          0.4323606 , 0.78654392]]])

# %%
samantha_gray=np.dstack(samantha_gray)

# %%
samantha_gray
# Out:
# array([[[0.4158949 , 0.59646168, 0.95915602, ..., 0.77472863,
#          0.00339294, 0.68978636]],
#
#        [[0.4158949 , 0.55812101, 0.95944356, ..., 0.77472863,
#          0.00339294, 0.69001861]],
#
#        [[0.4158949 , 0.62983227, 0.97185567, ..., 0.77472863,
#          0.00339294, 0.69079535]],
#
#        ...,
#
#        [[0.26467057, 0.88620445, 0.96225205, ..., 0.11514736,
#          0.59367745, 0.76277935]],
#
#        [[0.26008512, 0.88620445, 0.96225205, ..., 0.11371779,
#          0.59367745, 0.79060226]],
#
#        [[0.26374346, 0.88620445, 0.96225205, ..., 0.11352025,
#          0.59367745, 0.7989214 ]]])

# %%
josephine_gray=np.rollaxis(josephine_gray,axis=2,start=0)

# %%
josephine_gray.shape
# Out:
# (10, 262144, 1)

# %%
samantha_gray=np.rollaxis(samantha_gray,axis=2,start=0)

# %%
samantha_gray.shape
# Out:
# (10, 262144, 1)

# %%
tanya_gray=np.rollaxis(tanya_gray,axis=2,start=0)

# %%
tanya_gray.shape
# Out:
# (10, 262144, 1)
