# %%
import os
import warnings
warnings.simplefilter('ignore')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pip install scikit-image
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
from skimage.io import imread,imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
ajith=os.listdir('C:/Users/rasik/Actors/Ajith')

# %%
suriya=os.listdir('C:/Users/rasik/Actors/Suriya')

# %%
vijay=os.listdir('C:/Users/rasik/Actors/Vijay')

# %%
ajith
# Out:
# ['1.jpg',
#  '10.jpg',
#  '11.jpg',
#  '12.jpg',
#  '13.jpg',
#  '14.jpg',
#  '15.jpg',
#  '16.jpg',
#  '17.jpg',
#  '18.jpg',
#  '19.jpg',
#  '2.jpg',
#  '20.jpg',
#  '21.jpg',
#  '22.jpg',
#  '23.jpg',
#  '24.jpg',
#  '25.jpg',
#  '26.jpg',
#  '27.jpg',
#  '28.jpg',
#  '29.jpg',
#  '3.jpg',
#  '30.jpg',
#  '4.jpg',
#  '5.jpg',
#  '6.jpg',
#  '7.jpg',
#  '8.jpg',
#  '9.jpg']

# %%
suriya
# Out:
# ['1.jpg',
#  '10.jpg',
#  '11.jpg',
#  '12.jpg',
#  '13.jpg',
#  '14.jpg',
#  '15.jpg',
#  '16.jpg',
#  '17.jpg',
#  '18.jpg',
#  '19.jpg',
#  '2.jpg',
#  '20.jpg',
#  '21.jpg',
#  '22.jpg',
#  '23.jpg',
#  '24.jpg',
#  '25.jpg',
#  '26.jpg',
#  '27.jpg',
#  '28.jpg',
#  '29.jpg',
#  '3.jpg',
#  '30.jpg',
#  '4.jpg',
#  '5.jpg',
#  '6.jpg',
#  '7.jpg',
#  '8.jpg',
#  '9.jpg']

# %%
vijay
# Out:
# ['1.jpg',
#  '10.jpg',
#  '11.jpg',
#  '12.jpg',
#  '13.jpg',
#  '14.jpg',
#  '15.jpg',
#  '16.jpg',
#  '17.jpg',
#  '18.jpg',
#  '19.jpg',
#  '2.jpg',
#  '20.jpg',
#  '21.jpg',
#  '22.jpg',
#  '23.jpg',
#  '24.jpg',
#  '25.jpg',
#  '26.jpg',
#  '27.jpg',
#  '28.jpg',
#  '29.jpg',
#  '3.jpg',
#  '30.jpg',
#  '4.jpg',
#  '5.jpg',
#  '6.jpg',
#  '7.jpg',
#  '8.jpg',
#  '9.jpg']

# %%
limit=10
ajith_images=[None]*limit
j=0
for i in ajith:
    if(j<limit):
        ajith_images[j]=imread('C://Users//rasik/Actors//Ajith//'+i)
        j+=1
    else:
        break

# %%
limit=10
suriya_images=[None]*limit
j=0
for i in suriya:
    if(j<limit):
        suriya_images[j]=imread('C://Users//rasik//Actors//Suriya//'+i)
        j+=1
    else:
        break

# %%
limit=10
vijay_images=[None]*limit
j=0
for i in vijay:
    if(j<limit):
        vijay_images[j]=imread('C://Users//rasik//Actors//Vijay//'+i)
        j+=1
    else:
        break

# %%
view = imshow(ajith_images[9])
plt.show()

# %%
view = imshow(suriya_images[8])
plt.show()

# %%
view = imshow(vijay_images[8])
plt.show()

# %%
ajith_gray=[None]*limit
j=0
for i in ajith:
    if(j<limit):
        ajith_gray[j]=rgb2gray(ajith_images[j])
        j+=1
    else:
        break

# %%
view = imshow(ajith_gray[8])
plt.show()

# %% [markdown]
# #CHANGE IMAGE RGBA TO RGB

# %%
from skimage.color import rgba2rgb

# %%
suriya_rgb=[None]*limit
j=0
for i in suriya:
    if(j<limit):
        suriya_rgb[j]=rgba2rgb(suriya_images[j])
        j+=1
    else:
        break

# %% [markdown]
# #CHANGE IMAGE RGB TO GRAY

# %%
suriya_gray=[None]*limit
j=0
for i in suriya:
    if(j<limit):
        suriya_gray[j]=rgb2gray(suriya_rgb[j])
        j+=1
    else:
        break

# %%
view = imshow(suriya_gray[3])
plt.show()

# %%
vijay_gray=[None]*limit
j=0
for i in vijay:
    if(j<limit):
        vijay_gray[j]=rgb2gray(vijay_images[j])
        j+=1
    else:
        break

# %%
view = imshow(vijay_gray[9])
plt.show()

# %%
vijay_images[4].shape
# Out:
# (225, 225, 3)

# %%
for j in range (10):
    aj=ajith_gray[j]
    ajith_gray[j]=resize(aj,(512,512))

# %%
for j in range (10):
    sr=suriya_gray[j]
    suriya_gray[j]=resize(sr,(512,512))

# %%
for j in range (10):
    vj=vijay_gray[j]
    vijay_gray[j]=resize(vj,(512,512))

# %%
view = imshow(ajith_gray[9])
plt.show()

# %%
view = imshow(suriya_gray[1])
plt.show()

# %%
view = imshow(vijay_gray[9])
plt.show()

# %%
len_of_images_ajith=len(ajith_gray)

# %%
len_of_images_ajith
# Out:
# 10

# %%
len_of_images_suriya=len(suriya_gray)

# %%
len_of_images_suriya
# Out:
# 10

# %%
len_of_images_vijay=len(vijay_gray)

# %%
len_of_images_vijay
# Out:
# 10

# %%
image_size_ajith=ajith_gray[1].shape

# %%
image_size_ajith
# Out:
# (512, 512)

# %%
image_size_suriya=suriya_gray[1].shape

# %%
image_size_suriya
# Out:
# (512, 512)

# %%
image_size_vijay=vijay_gray[1].shape

# %%
image_size_vijay
# Out:
# (512, 512)

# %%
512*10
# Out:
# 5120

# %%
flatten_size_ajith=image_size_ajith[0]*image_size_ajith[1]

# %%
flatten_size_ajith
# Out:
# 262144

# %%
flatten_size_suriya=image_size_suriya[0]*image_size_suriya[1]

# %%
flatten_size_suriya
# Out:
# 262144

# %%
flatten_size_vijay=image_size_vijay[0]*image_size_vijay[1]

# %%
flatten_size_vijay
# Out:
# 262144

# %%
for i in range(len_of_images_ajith):
    ajith_gray[i]=np.ndarray.flatten(ajith_gray[i]).reshape(flatten_size_ajith,1)

# %%
for i in range(len_of_images_suriya):
    suriya_gray[i]=np.ndarray.flatten(suriya_gray[i]).reshape(flatten_size_suriya,1)

# %%
for i in range(len_of_images_vijay):
   vijay_gray[i]=np.ndarray.flatten(vijay_gray[i]).reshape(flatten_size_vijay,1)

# %%
ajith_gray=np.dstack(ajith_gray)

# %%
ajith_gray
# Out:
# array([[[0.97589985, 0.59448517, 0.93194771, ..., 0.92987294,
#          0.60476554, 0.        ]],
#
#        [[0.97587066, 0.59711998, 0.93194771, ..., 0.92987294,
#          0.60476554, 0.        ]],
#
#        [[0.97461072, 0.60628051, 0.93194771, ..., 0.92987294,
#          0.60476554, 0.        ]],
#
#        ...,
#
#        [[0.7375711 , 0.08738   , 0.11370181, ..., 0.84545137,
#          0.96754118, 0.        ]],
#
#        [[0.71178219, 0.08738   , 0.11599912, ..., 0.84545137,
#          0.96754118, 0.        ]],
#
#        [[0.71118476, 0.08738   , 0.11673727, ..., 0.84545137,
#          0.96754118, 0.        ]]])

# %%
suriya_gray=np.dstack(suriya_gray)

# %%
suriya_gray
# Out:
# array([[[0.87795993, 0.12808471, 0.34508427, ..., 0.49181673,
#          0.29000644, 0.86466569]],
#
#        [[0.91932022, 0.12808471, 0.3436107 , ..., 0.48866037,
#          0.28689836, 0.86405006]],
#
#        [[0.85176507, 0.12808471, 0.34630332, ..., 0.49166643,
#          0.26440568, 0.86482171]],
#
#        ...,
#
#        [[0.05768428, 0.09642152, 0.48368915, ..., 0.74108512,
#          0.37950304, 0.40420451]],
#
#        [[0.05768428, 0.09302559, 0.48226063, ..., 0.74108512,
#          0.35574945, 0.41293748]],
#
#        [[0.05768428, 0.09524262, 0.48304241, ..., 0.74108512,
#          0.35246713, 0.4059702 ]]])

# %%
vijay_gray=np.dstack(vijay_gray)

# %%
vijay_gray
# Out:
# array([[[0.71263091, 0.33112863, 0.28099836, ..., 0.5962586 ,
#          0.82163922, 0.85624152]],
#
#        [[0.71200313, 0.33112863, 0.27924174, ..., 0.59635951,
#          0.82163922, 0.8570491 ]],
#
#        [[0.71315026, 0.33112863, 0.28078414, ..., 0.5959933 ,
#          0.82163922, 0.85099226]],
#
#        ...,
#
#        [[0.17106188, 0.35392139, 0.11039694, ..., 0.47181081,
#          0.10463605, 0.66174569]],
#
#        [[0.16535327, 0.35644335, 0.11039694, ..., 0.48823673,
#          0.10606563, 0.65806922]],
#
#        [[0.16847738, 0.35718312, 0.11039694, ..., 0.48371048,
#          0.10626317, 0.65855941]]])

# %%
ajith_gray=np.rollaxis(ajith_gray,axis=2,start=0)

# %%
ajith_gray.shape
# Out:
# (10, 262144, 1)

# %%
suriya_gray=np.rollaxis(suriya_gray,axis=2,start=0)

# %%
suriya_gray.shape
# Out:
# (10, 262144, 1)

# %%
vijay_gray=np.rollaxis(vijay_gray,axis=2,start=0)

# %%
vijay_gray.shape
# Out:
# (10, 262144, 1)

# %%
ajith_gray=ajith_gray.reshape(len_of_images_ajith,flatten_size_ajith)

# %%
ajith_gray.shape
# Out:
# (10, 262144)

# %%
suriya_gray=suriya_gray.reshape(len_of_images_suriya,flatten_size_suriya)

# %%
suriya_gray.shape
# Out:
# (10, 262144)

# %%
vijay_gray=vijay_gray.reshape(len_of_images_vijay,flatten_size_vijay)

# %%
vijay_gray.shape
# Out:
# (10, 262144)

# %%
ajith_data=pd.DataFrame(ajith_gray)

# %%
ajith_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.975900  0.975871  0.974611  0.969931  0.962275  0.961290  0.965592
# 1  0.594485  0.597120  0.606281  0.622747  0.639871  0.657423  0.672070
# 2  0.931948  0.931948  0.931948  0.931948  0.931948  0.931948  0.932230
# 3  0.159681  0.162569  0.152088  0.141637  0.131514  0.121391  0.125038
# 4  0.550575  0.550575  0.550575  0.550575  0.550575  0.550575  0.550575
# 5  0.369888  0.369888  0.369888  0.369888  0.369888  0.369888  0.369888
# 6  0.035562  0.035562  0.035562  0.035711  0.037435  0.039158  0.040666
# 7  0.929873  0.929873  0.929873  0.929873  0.930071  0.930437  0.930802
# 8  0.604766  0.604766  0.604766  0.604766  0.604766  0.604766  0.604766
# 9  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.956647  0.938151  0.872386  ...  0.928796  0.945611  0.937676  0.915786
# ...

# %%
suriya_data=pd.DataFrame(suriya_gray)

# %%
suriya_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.877960  0.919320  0.851765  0.784210  0.748089  0.734578  0.721067
# 1  0.128085  0.128085  0.128085  0.128085  0.128085  0.128085  0.128085
# 2  0.345084  0.343611  0.346303  0.348996  0.352780  0.357081  0.361654
# 3  0.829916  0.831451  0.829990  0.828455  0.826920  0.825764  0.824637
# 4  0.650055  0.650055  0.650055  0.650055  0.650055  0.650055  0.650055
# 5  0.482224  0.483629  0.544292  0.527157  0.442336  0.368728  0.304004
# 6  0.447043  0.440334  0.448744  0.457154  0.462588  0.461186  0.459785
# 7  0.491817  0.488660  0.491666  0.494823  0.497979  0.500736  0.503461
# 8  0.290006  0.286898  0.264406  0.238795  0.211893  0.196699  0.183646
# 9  0.864666  0.864050  0.864822  0.865593  0.866201  0.866432  0.866663
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.719198  0.717696  0.717268  ...  0.058511  0.059134  0.058894  0.058649
# ...

# %%
vijay_data=pd.DataFrame(vijay_gray)

# %%
vijay_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.712631  0.712003  0.713150  0.714297  0.714665  0.714665  0.714717
# 1  0.331129  0.331129  0.331129  0.334723  0.338010  0.339536  0.342272
# 2  0.280998  0.279242  0.280784  0.282541  0.284297  0.288724  0.293749
# 3  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 4  0.541349  0.544581  0.532854  0.520202  0.497806  0.475410  0.450380
# 5  0.419702  0.406702  0.416575  0.429575  0.442575  0.441261  0.431868
# 6  0.949585  0.949585  0.949585  0.949585  0.949585  0.949585  0.949585
# 7  0.596259  0.596360  0.595993  0.595808  0.597532  0.599255  0.600978
# 8  0.821639  0.821639  0.821639  0.820149  0.818043  0.817718  0.817718
# 9  0.856242  0.857049  0.850992  0.845118  0.839670  0.834791  0.832754
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.715110  0.715502  0.716336  ...  0.223394  0.219612  0.211269  0.202926
# ...

# %%
ajith_data["label"]="ajith"

# %%
suriya_data["label"]="suriya"

# %%
vijay_data["label"]="vijay"

# %%
ajith_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.975900  0.975871  0.974611  0.969931  0.962275  0.961290  0.965592
# 1  0.594485  0.597120  0.606281  0.622747  0.639871  0.657423  0.672070
# 2  0.931948  0.931948  0.931948  0.931948  0.931948  0.931948  0.932230
# 3  0.159681  0.162569  0.152088  0.141637  0.131514  0.121391  0.125038
# 4  0.550575  0.550575  0.550575  0.550575  0.550575  0.550575  0.550575
# 5  0.369888  0.369888  0.369888  0.369888  0.369888  0.369888  0.369888
# 6  0.035562  0.035562  0.035562  0.035711  0.037435  0.039158  0.040666
# 7  0.929873  0.929873  0.929873  0.929873  0.930071  0.930437  0.930802
# 8  0.604766  0.604766  0.604766  0.604766  0.604766  0.604766  0.604766
# 9  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.956647  0.938151  0.872386  ...  0.945611  0.937676  0.915786  0.874541
# ...

# %%
suriya_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.877960  0.919320  0.851765  0.784210  0.748089  0.734578  0.721067
# 1  0.128085  0.128085  0.128085  0.128085  0.128085  0.128085  0.128085
# 2  0.345084  0.343611  0.346303  0.348996  0.352780  0.357081  0.361654
# 3  0.829916  0.831451  0.829990  0.828455  0.826920  0.825764  0.824637
# 4  0.650055  0.650055  0.650055  0.650055  0.650055  0.650055  0.650055
# 5  0.482224  0.483629  0.544292  0.527157  0.442336  0.368728  0.304004
# 6  0.447043  0.440334  0.448744  0.457154  0.462588  0.461186  0.459785
# 7  0.491817  0.488660  0.491666  0.494823  0.497979  0.500736  0.503461
# 8  0.290006  0.286898  0.264406  0.238795  0.211893  0.196699  0.183646
# 9  0.864666  0.864050  0.864822  0.865593  0.866201  0.866432  0.866663
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.719198  0.717696  0.717268  ...  0.059134  0.058894  0.058649  0.058276
# ...

# %%
vijay_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.712631  0.712003  0.713150  0.714297  0.714665  0.714665  0.714717
# 1  0.331129  0.331129  0.331129  0.334723  0.338010  0.339536  0.342272
# 2  0.280998  0.279242  0.280784  0.282541  0.284297  0.288724  0.293749
# 3  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 4  0.541349  0.544581  0.532854  0.520202  0.497806  0.475410  0.450380
# 5  0.419702  0.406702  0.416575  0.429575  0.442575  0.441261  0.431868
# 6  0.949585  0.949585  0.949585  0.949585  0.949585  0.949585  0.949585
# 7  0.596259  0.596360  0.595993  0.595808  0.597532  0.599255  0.600978
# 8  0.821639  0.821639  0.821639  0.820149  0.818043  0.817718  0.817718
# 9  0.856242  0.857049  0.850992  0.845118  0.839670  0.834791  0.832754
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.715110  0.715502  0.716336  ...  0.219612  0.211269  0.202926  0.193911
# ...

# %%
actor=pd.concat([ajith_data,suriya_data,vijay_data])

# %%
actor
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.975900  0.975871  0.974611  0.969931  0.962275  0.961290  0.965592
# 1  0.594485  0.597120  0.606281  0.622747  0.639871  0.657423  0.672070
# 2  0.931948  0.931948  0.931948  0.931948  0.931948  0.931948  0.932230
# 3  0.159681  0.162569  0.152088  0.141637  0.131514  0.121391  0.125038
# 4  0.550575  0.550575  0.550575  0.550575  0.550575  0.550575  0.550575
# 5  0.369888  0.369888  0.369888  0.369888  0.369888  0.369888  0.369888
# 6  0.035562  0.035562  0.035562  0.035711  0.037435  0.039158  0.040666
# 7  0.929873  0.929873  0.929873  0.929873  0.930071  0.930437  0.930802
# 8  0.604766  0.604766  0.604766  0.604766  0.604766  0.604766  0.604766
# 9  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0  0.877960  0.919320  0.851765  0.784210  0.748089  0.734578  0.721067
# 1  0.128085  0.128085  0.128085  0.128085  0.128085  0.128085  0.128085
# ...

# %%
from sklearn.utils import shuffle

# %%
kollywood_indexed=shuffle(actor).reset_index()

# %%
kollywood_indexed
# Out:
#     index         0         1         2         3         4         5  \
# 0       8  0.290006  0.286898  0.264406  0.238795  0.211893  0.196699
# 1       7  0.596259  0.596360  0.595993  0.595808  0.597532  0.599255
# 2       4  0.550575  0.550575  0.550575  0.550575  0.550575  0.550575
# 3       5  0.482224  0.483629  0.544292  0.527157  0.442336  0.368728
# 4       6  0.035562  0.035562  0.035562  0.035711  0.037435  0.039158
# 5       2  0.931948  0.931948  0.931948  0.931948  0.931948  0.931948
# 6       6  0.949585  0.949585  0.949585  0.949585  0.949585  0.949585
# 7       2  0.280998  0.279242  0.280784  0.282541  0.284297  0.288724
# 8       4  0.541349  0.544581  0.532854  0.520202  0.497806  0.475410
# 9       0  0.877960  0.919320  0.851765  0.784210  0.748089  0.734578
# 10      0  0.712631  0.712003  0.713150  0.714297  0.714665  0.714665
# 11      1  0.128085  0.128085  0.128085  0.128085  0.128085  0.128085
# ...

# %%
kollywood_actors=kollywood_indexed.drop(['index'],axis=1)

# %%
kollywood_actors
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.290006  0.286898  0.264406  0.238795  0.211893  0.196699  0.183646
# 1   0.596259  0.596360  0.595993  0.595808  0.597532  0.599255  0.600978
# 2   0.550575  0.550575  0.550575  0.550575  0.550575  0.550575  0.550575
# 3   0.482224  0.483629  0.544292  0.527157  0.442336  0.368728  0.304004
# 4   0.035562  0.035562  0.035562  0.035711  0.037435  0.039158  0.040666
# 5   0.931948  0.931948  0.931948  0.931948  0.931948  0.931948  0.932230
# 6   0.949585  0.949585  0.949585  0.949585  0.949585  0.949585  0.949585
# 7   0.280998  0.279242  0.280784  0.282541  0.284297  0.288724  0.293749
# 8   0.541349  0.544581  0.532854  0.520202  0.497806  0.475410  0.450380
# 9   0.877960  0.919320  0.851765  0.784210  0.748089  0.734578  0.721067
# 10  0.712631  0.712003  0.713150  0.714297  0.714665  0.714665  0.714717
# 11  0.128085  0.128085  0.128085  0.128085  0.128085  0.128085  0.128085
# ...

# %%
kollywood_actors.to_csv("recognition image source code.csv")

# %%
x=kollywood_actors.values[:,:-1]

# %%
y=kollywood_actors.values[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (24, 262144)

# %%
x_test.shape
# Out:
# (6, 262144)

# %%
y_train.shape
# Out:
# (24,)

# %%
y_test.shape
# Out:
# (6,)

# %%
from sklearn import decomposition

# %%
pca = decomposition.PCA(n_components=20,whiten=True,random_state=1)

# %%
pca.fit(x_train)
# Out:
# PCA(n_components=20, random_state=1, whiten=True)

# %%
x_train_pca=pca.transform(x_train)
x_test_pca=pca.transform(x_test)

# %%
x_train_pca.shape
# Out:
# (24, 20)

# %%
x_test_pca.shape
# Out:
# (6, 20)
